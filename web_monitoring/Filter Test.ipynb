# %%
import pandas as pd

# %%
df = pd.read_csv('Test File.csv')

# %%
df.head()
# Out:
#    Unnamed: 0                                                new  offset  \
# 0           0                                                Nov  2330.0
# 1           1  <td class="c" id="displayMonthEl" title="You a...  2424.0
# 2           2                                                Jan  2857.0
# 3           3                                Library of Virginia  6686.0
# 4           4                                Library of Virginia  7065.0
#
#                                                  old   state
# 0                                                Oct  Change
# 1  <td class="c" id="displayMonthEl" title="You a...  Change
# 2                                                Dec  Change
# 3                             Alabama State Archives  Change
# 4                             Alabama State Archives  Change

# %%
import filtering as fil

# %%
df = fil.df_filter(df)

# %%
df
# Out:
#     Unnamed: 0                                                new    offset  \
# 0          0.0                                                Nov    2330.0
# 1          0.1  <td class="c" id="displayMonthEl" title="You a...    2424.0
# 2          2.0                                                Jan    2857.0
# 3          3.0                                Library of Virginia    6686.0
# 4          4.0                                Library of Virginia    7065.0
# 5          5.0  <a href="http://www.lva.virginia.gov">http://w...    7293.0
# 6          6.0                                            Library    7583.0
# 7          7.0  Virginia serves as the Commonwealth's archival...    7679.0
# 8          8.0                                             as one    7862.0
# 9          9.0  nation's premier research institutions for Vir...    7966.0
# 10        10.0  culture. The library holdings attract research...    8146.0
# ...
